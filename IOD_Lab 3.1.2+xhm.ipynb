# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 3.1.2
# # *Exploring Data*

# %% [markdown]
# ## Part 1: Continuous and Categorical Data

# %% [markdown]
# When we explore a dataset we usually produce textual and graphical output together, starting with a high-level overview of the data and gradually drilling down into the individual features and relationships between them.

# %% [markdown]
# Our most important libraries for this task are:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Override default figure sizing:
pylab.rcParams['figure.figsize'] = (10, 6)
sns.set(color_codes = True)

# %% [markdown]
# ## Data Profiling
#
# We actually start profiling the data when we first load it and check for input errors, as in the last lab. Once we have a DataFrame we can work with, however, things start getting more interesting.

# %% [markdown]
# **Load the file "bikeshare.csv" into a DataFrame named `bikes`, and check that it was loaded properly:**

# %%
#ANSWER:
bikes = pd.read_csv('C:\\Users\\apple\\Downloads\\bikeshare.csv', header = 0)
bikes.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# We may want our program to capture particular features of the dataset into variables, but if we just want to get a feel for the data it is easier to use a higher-level Pandas method like `describe()`:
#
# **Use `describe` to get the description of datasets.**

# %%
#ANSWER:
bikes.describe().transpose()
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# ...

# %% [markdown]
# ### Continuous Data

# %% [markdown]
# We may have to do a lot of work before we can produce presentable graphics, but we can start creating simple visualisations as soon as we have a DataFrame.
#
# We usually start charting variables one-by-one (although when several have the same range it may be preferable to overlay them, using a different colour or symbol for each).

# %% [markdown]
# **Use the `scatter` method of Pandas to create a scatter plot of `windspeed`, `temp`:**

# %%
#ANSWER
x=bikes.windspeed
y=bikes.temp
#colors = (0,0,0)
area = np.pi*3
#plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.scatter(x, y,  alpha=0.5)
plt.title('Scatter plot ')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **The `scatter` method has various parameters for controlling the appearance of the chart. Experiment with `s` , `linewidths`, and `alpha` below:**

# %%
#ANSWER


#plt.scatter(x, y, s=area, c=colors, alpha=0.5)
bikes.plot.scatter(x="windspeed", y="temp" , alpha=0.5, c="green",\
                
                title="This is the title",xlabel='x',ylabel='y' )
plt.show()

# %% [markdown]
# The scatterplot shows us the raw data. Our next step is usually to see how it is distributed, which is what the histogram is for:
#
# > A histogram is used for continuous data, where the bins represent ranges of data, while a bar chart is a plot of categorical variables. <sup>[1](#histfootnote)</sup>
#
# - **Identify continuous varaibles**
# - **Create histogram for those variables**

# %%
bikes.windspeed.hist(bins=20)
plt.show()

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
#ANSWER
bikes.atemp.hist(bins=20)
plt.show()

# %% [markdown]
# What do the horizontal and vertical axes represent?

# %% [markdown]
# #### ANSWER:
#     horiz = magnitude of `atemp`, apparently normalised to [0, 1], discretised into bins of width 0.1;
#     vertical = counts of samples in each bin.

# %% [markdown]
# *NOTE: Samples in a given bin are greater than the axis value of its left side and less than or equal to the axis value of its right side. (The left-most bin is an exception: it represents greater than or equal to.)*

# %% [markdown]
# The box-and-whisker plot provides a compact view of the major percentiles of the distribution:
#
# **Make a box and whisker plot for the column ``atemp``.**
#
# > The box extends from the lower to
# upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data.  Flier points are those past the end of the whiskers.

# %%
#ANSWER
bikes.windspeed.boxplot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-fec2acc11cb1> in <module>
#       1 #ANSWER
# ----> 2 bikes.windspeed.boxplot()
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'boxplot'

# %%
sns.boxplot(data=bikes[['windspeed','atemp']])
# Out:
# <AxesSubplot:>

# %%
#ANSWER
#bikes.windspeed.boxplot()
#boxplot_windspeed = bikes.boxplot(column=['windspeed'])
#boxplot = bikes.boxplot(column=['windspeed'])
boxplot = bikes.boxplot(column=['windspeed', 'atemp'])
plt.show()

# %% [markdown]
# This kind of plot really shines when we want to show several distributions at once (as long as they have compatible ranges).
#
# **Plot `atemp` and `windspeed` together. Change labels accordingly.**

# %%
#ANSWER

# %% [markdown]
# ### Classified Data
#
# Samples may represent different classes according to one or more categorical variables. Sometimes our goal is to discover these classes, or to train a classification model from samples that have been manually classified.

# %% [markdown]
# Here, the famous "Iris" dataset gets loaded from the UCI repository:

# %%
import urllib

# get Iris dataset from UCI Machine Learning Repository:
url = "http://goo.gl/HppjFh" 
raw_data = urllib.request.urlopen(url)

# load the CSV file:
iris_data = pd.read_csv(raw_data, delimiter = ",", 
                        names = ('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))

# %% [markdown]
# Note that the column names were overridden by the `names` argument of the Pandas `read.csv` method. This requires prior knowledge of the dataset, which we would normally get from a data dictionary (although sometimes we just have to figure it out for ourselves).

# %% [markdown]
# **Print the first few rows of this DataFrame:**

# %%
#ANSWER
iris_data.head()
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# In this dataset, `species` has several possible values (representing the classes of the samples).
#
# **Find out distinct number of `species` and number of sample for each `species` in this dataset.**

# %% [markdown]
# # Some questions below; don't understand

# %%
iris_data.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris_data[iris_data.species=="Iris-setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
#ANSWER
#iris_data.species.unique()
#iris_data[iris_data[["species"]]=="Iris-setosa"]
#len(iris_data[iris_data.species=="Iris-setosa"])
print("Iris-setosa : "+  str( len(iris_data[iris_data.species=="Iris-setosa"])  ))
print("Iris-versicolor : "+  str( len(iris_data[iris_data.species=="Iris-versicolor"])  ))
print("Iris-virginica : "+  str( len(iris_data[iris_data.species=="Iris-virginica"])  ))
# Out:
# Iris-setosa : 50
# Iris-versicolor : 50
# Iris-virginica : 50

# %% [markdown]
# We often need to capture the number of classes in code. We can do this with a variation on the above. Try this below:

# %% [markdown]
# We often need to calculate aggregate values within subgroups of the dataset. The Pandas DataFrame method for this is `groupby`.
#
# **Apply the `groupby` method to get `mean` of `sepal_length` and `sepal_width` for the above dataset.**

# %% [markdown]
# # something to notice about the order: groupby the DataFrame and then select the Column

# %%
#ANSWER 
#df.groupby(by=["b"]).sum()
iris_data.groupby(by=["species"]).sepal_length.mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %% [markdown]
# The Pandas `plot` method provides a quick way to produce a scatter plot.
#
# **Draw a Scatterplot showing sepal width and length using the Pandas `plot` method.**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
#ANSWER
plt.figure(figsize=(10,12))
sns.lmplot(x="sepal_width", y="sepal_length" , hue="species", 
           data=iris_data,fit_reg = True,palette=['green','orange','brown'])
plt.title("Scatterplot showing sepal width and length using seaborn ")
plt.xlim()
plt.ylim()
plt.show()

# %% [markdown]
# **[BONUS] Draw a Scatterplot showing sepal width and length. Without using seaborn.**

# %%
#ANSWER
plt.figure(figsize=(12,10))
iris_data.plot.scatter(x="sepal_width", y="sepal_length" , alpha=1, c="green",\
                
                title="Scatterplot showing sepal width and length using the Pandas ",xlabel='x',ylabel='y' )
plt.show()
#iris_data.scatter(x='iris_data.sepal_width',y='iris_data.sepal_length')

# %% [markdown]
# **Draw a Barplot showing sepal width and length using the Pandas plot method.**

# %%
#ANSWER

# %%
iris_data.plot.bar(x="sepal_width", y="sepal_length", rot=0)

plt.show()

# %% [markdown]
# Draw a Scatterplot showing sepal width and length using the Pandas plot method.
#
# **[BONUS] Set `title`, `xlabel`, `ylabel` to the plot**

# %%
#ANSWER
iris_data.plot.bar(x="sepal_width", y="sepal_length",rot =0)
plt.title("This is the title")
plt.xlabel("x")
plt.ylabel("y")                  
plt.show()

# %% [markdown]
# In this dataset we have also `petal_width`, `petal_length`.
#
# **Try to draw Scatterplot using these variables.**

# %%
# ANSWER
iris_data.plot.scatter(x="petal_width", y="petal_length" , alpha=1, c="blue",\
                
                title="Scatterplot showing petal width and length using the Pandas " )
plt.show()

# %% [markdown]
# In this case, we already have different species, so we can colour the points accordingly. This is easy to do using the Seaborn library. Try using `lmplot` of seaborn library and use the parameter `hue` and `fit_reg = False`.
#
# **Draw a Scatterplot showing sepal width and length.**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
#ANSWER
plt.figure(figsize=(10,12))
sns.lmplot(x="petal_width", y="petal_length" , hue="species", 
           data=iris_data,fit_reg = False,palette=['green','orange','brown'])
plt.title("Scatterplot showing sepal width and length using seaborn ")
plt.xlim(0,3)
plt.ylim(0,8)
plt.show()

# %% [markdown]
# To find out why this function is called `lmplot`, try it again with `fit_reg` = True:
#
# **Draw a Scatterplot showing sepal width and length:**

# %%
#ANSWER
plt.figure(figsize=(10,12))
sns.lmplot(x="petal_width", y="petal_length" , hue="species", 
           data=iris_data,fit_reg = True,palette=['green','orange','brown'])
plt.xlim(0,3)
plt.ylim(0,8)
plt.show()

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:

# %% [markdown]
# The Seaborn `jointplot` function charts a correlation along with both distributions:
#
# **Draw a jointplot showing sepal width and length:**

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# ANSWER
p = sns.jointplot(data=iris_data,x="sepal_width", y="sepal_length",kind='scatter')

# %%
p2 = sns.jointplot(data=iris_data,x="sepal_width", y="sepal_length",kind='hex')

# %% [markdown]
# When we want to see all the correlations at once, we can use `pairplot`:
#
# **Draw a `pairplot` of the dataset:**

# %%
# ANSWER
g = sns.pairplot(data=iris_data)

# %% [markdown]
# And, if the classes are known, we can apply colour using the `hue` parameter. Try this below:

# %%
# ANSWER
g = sns.pairplot(data=iris_data,hue="species")

# %% [markdown]
# Note that this gave us class-based distributions instead of an overall histogram, as well.

# %% [markdown]
# When we want to see numerical values of the correlations, the Pandas `corr` method provides a table of pair-wise correlations between the features in the DataFrame:

# %%
# ANSWER
corr_matrix = iris_data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
       'species']].corr()

corr_matrix.style.background_gradient(cmap='coolwarm').set_precision(4)
# Out:
# <style  type="text/css" >
# #T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow0_col0,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow1_col1,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow2_col2,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow0_col1{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow0_col2{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow0_col3{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow1_col0,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow1_col2,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow1_col3,#T_c330ad0d_4ff9_11eb_96d6_542696d1d87drow2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ### High-Level Data Profiling Libraries

# %% [markdown]
# We need to master the basic data profiling functions because we will by using them frequently, for exploring data and answering ad hoc questions. In a production solution, we may need to incorporate specific data profiling code into our script so that we can automate data cleaning. However, when we just want to examine the data interactively before we start modelling, it is easier to use a high-level library like the following:
#
# > pip install pandas_profiling

# %%
# ANSWER
import pandas_profiling
df = pd.read_csv("C:\\Users\\apple\\Downloads\\Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong               GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775000, 6.083330)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333    (56.183330, 10.233330)
# ...

# %% [markdown]
# Use `ProfileReport` of `pandas_profiling` to get the overview of the dataset.

# %%
# ANSWER
pandas_profiling.ProfileReport(df)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-01-06 09:37:35.991779&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# For **HOMEWORK**: check out the `pydqc` library.

# %% [markdown]
# ## Part 2: Time Series and Geospatial Data

# %% [markdown]
# ## Time Series
#
# A time series is basically a series or a data frame with a time-based index column. Working with time series introduces a lot of challenges and possibilities, but most tasks are catered for by the standard libraries in Python.

# %% [markdown]
# Here is a history of air passenger counts by month, loaded into an ordinary DataFrame:

# %%
airpass = pd.read_csv('C:\\Users\\apple\\Downloads\\AirPassengers.csv')
airpass.head(30)
# Out:
#    TravelDate  Passengers
# 0    1/1/1949         112
# 1    2/1/1949         118
# 2    3/1/1949         132
# 3    4/1/1949         129
# 4    5/1/1949         121
# 5    6/1/1949         135
# 6    7/1/1949         148
# 7    8/1/1949         148
# 8    9/1/1949         136
# 9   10/1/1949         119
# 10  11/1/1949         104
# 11  12/1/1949         118
# 12   1/1/1950         115
# 13   2/1/1950         126
# 14   3/1/1950         141
# 15   4/1/1950         135
# 16   5/1/1950         125
# 17   6/1/1950         149
# 18   7/1/1950         170
# 19   8/1/1950         170
# 20   9/1/1950         158
# 21  10/1/1950         133
# 22  11/1/1950         114
# 23  12/1/1950         140
# 24   1/1/1951         145
# 25   2/1/1951         150
# 26   3/1/1951         178
# 27   4/1/1951         163
# 28   5/1/1951         172
# 29   6/1/1951         178

# %%
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
airpass.dtypes
# Out:
# TravelDate    object
# Passengers     int64
# dtype: object

# %% [markdown]
# Before going any further, the `TravelDate` column needs to be converted to the `datetime` type.

# %%
# ANSWER
airpass['TravelDate']=pd.to_datetime(airpass['TravelDate'])

# %%
airpass.loc[0, 'TravelDate'].day_name()
# Out:
# 'Saturday'

# %%
airpass.dtypes
# Out:
# TravelDate    datetime64[ns]
# Passengers             int64
# dtype: object

# %% [markdown]
# Set `TravelDate` as index

# %%
# ANSWER

airpass.set_index('TravelDate',inplace=True)
airpass
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# Now, Pandas knows that the first column of this DataFrame is a datetime index, so it only shows one column of data:
#
# Use `head` to check.

# %%
# ANSWER
airpass.head()
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Here's how to see the values of the index:

# %%
airpass.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='TravelDate', length=144, freq=None)

# %% [markdown]
# If we had multiple data columns but we only wanted to work with a time series of one of them, we could pull that column into a 1D time series:

# %%
ts = airpass['Passengers']
ts
# Out:
# TravelDate
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Passengers, Length: 144, dtype: int64

# %% [markdown]
# We use the datetime index exactly like a row number index:

# %%
print(ts['1949-01-01'])
# Out:
# 112

# %% [markdown]
# Or, we can refer to the row by its datetime equivalent:

# %%
from datetime import datetime
print(ts[datetime(1949,1,1 )])
# Out:
# 112

# %% [markdown]
# Happily, Pandas makes it easy to slice data at a courser grain. We can refer to a whole year of data by omitting the month and day form the index:

# %%
print(ts['1949'])
# Out:
# TravelDate
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# Name: Passengers, dtype: int64

# %% [markdown]
# The most basic way to plot a time series is to let Pandas apply the default:

# %%
ts.plot();

# %% [markdown]
# ## Geospatial Data
#
# Geospatial data is map-based (although what constitutes a "map" can go beyond the familiar). Ultimately, geographic data  occurs either in bitmap (raster) form or vector (resizeable polygons). It is not unusual for the two kinds of data to be used together.
#
# Because borders are often complex, following river courses, mountain ranges, and so on, the files that describe their geometries can be large. To reduce file sizes and image rendering times, we prefer to work with polygons that are no more detailed than the maximum resolution we need for our task. For this reason, geospatial files are often available at several different resolutions.

# %% [markdown]
# There are several popular options for working with maps in Python. We will use folium for its breadth and its use of open-source data.

# %%
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import folium
from folium.plugins import MarkerCluster
#pip install folium

# %%
# Read SF Incidents data
crime_csv =pd.read_csv('C:\\Users\\apple\\Downloads\\SFPD_Incidents-Current_Year_2015.csv',header=0)
crime_csv.head()
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1   150827213       ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4   150827213       ASSAULT              MAYHEM WITH A KNIFE    Sunday
#
#          Date   Time PdDistrict      Resolution                   Address  \
# 0  09/20/2015  23:54   RICHMOND       UNFOUNDED  3000 Block of CLEMENT ST
# 1  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 2  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 3  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 4  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
#
#             X          Y                               Location
# ...

# %%
crime_csv.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location'],
#       dtype='object')

# %% [markdown]
# Convert `Date` Column to DateTime and set as index

# %%
# ANSWER
crime_csv['Date']=pd.to_datetime(crime_csv['Date'])
crime_csv.set_index('Date',inplace=True)
crime_csv.head()
# Out:
#             IncidntNum      Category                         Descript  \
# Date
# 2015-09-20   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED
# 2015-09-20   150827213       ASSAULT      INFLICT INJURY ON COHABITEE
# 2015-09-20   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE
# 2015-09-20   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)
# 2015-09-20   150827213       ASSAULT              MAYHEM WITH A KNIFE
#
#            DayOfWeek   Time PdDistrict      Resolution  \
# Date
# 2015-09-20    Sunday  23:54   RICHMOND       UNFOUNDED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
#
#                              Address           X          Y  \
# Date
# 2015-09-20  3000 Block of CLEMENT ST -122.491851  37.781756
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# ...

# %% [markdown]
# Draw a timeseries plot to visualize number of crimes for each day.

# %%
#pd.to_list(crime_csv['Location'])
ts=crime_csv.IncidntNum
ts
# Out:
# Date
# 2015-09-20    150827188
# 2015-09-20    150827213
# 2015-09-20    150827213
# 2015-09-20    150827213
# 2015-09-20    150827213
#                 ...
# 2015-01-02    150007653
# 2015-01-02    150008457
# 2015-01-02    150005538
# 2015-01-02    150005306
# 2015-01-02    150042029
# Name: IncidntNum, Length: 112331, dtype: int64

# %%
crime_csv.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# dtype: object

# %%
# ANSWER
ts.plot();

# %% [markdown]
# Using folium we can easily create a map. As it's SF data, by default we are using SF location.

# %%
def generateBaseMap(default_location=[37.76, -122.45], default_zoom_start=12):
    '''
    Create a base map
    '''
    base_map = folium.Map(
        location = default_location
        , control_scale = True
        , zoom_start = default_zoom_start
    )
    
    return base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Add a marker in the map using `Folium.Marker` for first 100 rows of the dataset.

# %%
#popup = "London"
#london_marker = folium.Marker([37.76, -122.45], popup=popup)
#base_map.add_child(london_marker)
#base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
# for speed purposes
MAX_RECORDS = 100
  
# create empty map zoomed in on San Francisco
#map = folium.Map(location=SF_COORDINATES, zoom_start=12)
 
# add a marker for every record in the filtered data, use a clustered view
for each in crime_csv[0:MAX_RECORDS].iterrows():
        location = [each[1]['Y'],each[1]['X']]
        #icons = [folium.Icon(icon="car", prefix="fa")]
        folium.Marker(location, icon=folium.Icon(color='blue',icon='car',prefix="fa")).add_to(base_map)
        
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#help(folium.Icon)

# %%
#locations = list(zip(crime_csv.Y[:10],crime_csv.X[:10]))
#locations = list(zip(accident_data.Latitude, accident_data.Longitude))
#icons = [folium.Icon(icon="car", prefix="fa") for _ in range(len(locations))]
#cluster = folium.Marker(locations=locations, icons=icons)
#cluster = MarkerCluster(locations=locations,icons=icons,)
#base_map.add_child(cluster)
#base_map

# %% [markdown]
# Add a cricle in the map using `Folium Circle` for first 100 rows of the dataset.

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
# for speed purposes
MAX_RECORDS = 100
  
# create empty map zoomed in on San Francisco
#map = folium.Map(location=SF_COORDINATES, zoom_start=12)
 
# add a marker for every record in the filtered data, use a clustered view
for each in crime_csv[0:MAX_RECORDS].iterrows():
        location = [each[1]['Y'],each[1]['X']]
        #icons = [folium.Icon(icon="car", prefix="fa")]
        folium.Circle(location,fill=True, ).add_to(base_map)
        
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# [BONUS] Create a heatmap of the incident happened in SF.

# %% [markdown]
# **HOMEWORK** Explore Folium as mush as you can.
#
# **HOMEWORK** Explore GeoPandas

# %% [markdown]
# # Part 3 Datetime-Timeseries Pandas

# %%
#d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
d_parser = lambda x: pd.datetime.strptime(x, '%m/%d/%Y')
df = pd.read_csv('C:\\Users\\apple\\Downloads\\SFPD_Incidents-Current_Year_2015.csv',header=0,\
                 parse_dates=['Date'], date_parser=d_parser)
df.head()
# Out:
# <ipython-input-377-c50906e585ba>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%m/%d/%Y')
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1   150827213       ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4   150827213       ASSAULT              MAYHEM WITH A KNIFE    Sunday
#
#         Date   Time PdDistrict      Resolution                   Address  \
# 0 2015-09-20  23:54   RICHMOND       UNFOUNDED  3000 Block of CLEMENT ST
# 1 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 2 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# ...

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Sunday'

# %%
df['Date'].dt.day_name()
# Out:
# 0         Sunday
# 1         Sunday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#            ...
# 112326    Friday
# 112327    Friday
# 112328    Friday
# 112329    Friday
# 112330    Friday
# Name: Date, Length: 112331, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#         IncidntNum        Category                         Descript DayOfWeek  \
# 0        150827188    NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1        150827213         ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2        150827213         ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3        150827213         ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4        150827213         ASSAULT              MAYHEM WITH A KNIFE    Sunday
# ...            ...             ...                              ...       ...
# 112326   150007653           FRAUD     CREDIT CARD, THEFT BY USE OF    Friday
# 112327   150008457    NON-CRIMINAL                    LOST PROPERTY    Friday
# 112328   150005538  OTHER OFFENSES                TRAFFIC VIOLATION    Friday
# 112329   150005306    NON-CRIMINAL                    LOST PROPERTY    Friday
# 112330   150042029    NON-CRIMINAL     DEATH REPORT, NATURAL CAUSES    Friday
#
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2015-01-02 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2015-09-20 00:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('261 days 00:00:00')

# %%
df
# Out:
#         IncidntNum        Category                         Descript DayOfWeek  \
# 0        150827188    NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1        150827213         ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2        150827213         ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3        150827213         ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4        150827213         ASSAULT              MAYHEM WITH A KNIFE    Sunday
# ...            ...             ...                              ...       ...
# 112326   150007653           FRAUD     CREDIT CARD, THEFT BY USE OF    Friday
# 112327   150008457    NON-CRIMINAL                    LOST PROPERTY    Friday
# 112328   150005538  OTHER OFFENSES                TRAFFIC VIOLATION    Friday
# 112329   150005306    NON-CRIMINAL                    LOST PROPERTY    Friday
# 112330   150042029    NON-CRIMINAL     DEATH REPORT, NATURAL CAUSES    Friday
#
# ...

# %%
filt = (df['Date'] >= pd.to_datetime('2015-01-01')) & (df['Date'] < pd.to_datetime('2015-01-31'))
df.loc[filt]
# Out:
#         IncidntNum         Category  \
# 99960    150094440    VEHICLE THEFT
# 99961    156027277    LARCENY/THEFT
# 99962    150096781  STOLEN PROPERTY
# 99963    150096781         WARRANTS
# 99964    150096781    VEHICLE THEFT
# ...            ...              ...
# 112326   150007653            FRAUD
# 112327   150008457     NON-CRIMINAL
# 112328   150005538   OTHER OFFENSES
# 112329   150005306     NON-CRIMINAL
# 112330   150042029     NON-CRIMINAL
#
#                                                  Descript DayOfWeek  \
# 99960                                   STOLEN AUTOMOBILE    Friday
# 99961                        GRAND THEFT FROM LOCKED AUTO    Friday
# 99962   STOLEN PROPERTY, POSSESSION WITH KNOWLEDGE, RE...    Friday
# 99963                                      WARRANT ARREST    Friday
# 99964                                   STOLEN AUTOMOBILE    Friday
# ...                                                   ...       ...
# ...

# %%
df.head()
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1   150827213       ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4   150827213       ASSAULT              MAYHEM WITH A KNIFE    Sunday
#
#         Date   Time PdDistrict      Resolution                   Address  \
# 0 2015-09-20  23:54   RICHMOND       UNFOUNDED  3000 Block of CLEMENT ST
# 1 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 2 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 3 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 4 2015-09-20  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
#
#             X          Y                               Location
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             IncidntNum        Category                         Descript  \
# Date
# 2015-09-20   150827188    NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED
# 2015-09-20   150827213         ASSAULT      INFLICT INJURY ON COHABITEE
# 2015-09-20   150827213         ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE
# 2015-09-20   150827213         ASSAULT           CHILD ABUSE (PHYSICAL)
# 2015-09-20   150827213         ASSAULT              MAYHEM WITH A KNIFE
# ...                ...             ...                              ...
# 2015-01-02   150007653           FRAUD     CREDIT CARD, THEFT BY USE OF
# 2015-01-02   150008457    NON-CRIMINAL                    LOST PROPERTY
# 2015-01-02   150005538  OTHER OFFENSES                TRAFFIC VIOLATION
# 2015-01-02   150005306    NON-CRIMINAL                    LOST PROPERTY
# 2015-01-02   150042029    NON-CRIMINAL     DEATH REPORT, NATURAL CAUSES
#
#            DayOfWeek   Time  PdDistrict      Resolution  \
# Date
# ...

# %%
df.loc['2015-09']['IncidntNum'].max()
# Out:
# 159005315

# %%
# %matplotlib inline

# %%
df.loc['2015']['IncidntNum'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.loc['2015-03': "2015-01"]['IncidntNum'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#dfN=df.loc['IncidntNum'].resample('D').max()
dfN= df.loc['2015-03': "2015-01"]['IncidntNum']

# %%
dfN
# Out:
# Date
# 2015-03-01    150447344
# 2015-03-01    150188372
# 2015-03-01    150188366
# 2015-03-01    150188510
# 2015-03-01    150188338
#                 ...
# 2015-02-01    150528063
# 2015-02-01    150500629
# 2015-02-01    156023996
# 2015-02-01    150549495
# 2015-02-01    150332206
# Name: IncidntNum, Length: 12613, dtype: int64

# %%
dfN.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
#               IncidntNum           X          Y
# Date
# 2015-01-04  1.511708e+08 -122.421792  37.769112
# 2015-01-11  1.509222e+08 -122.421451  37.767991
# 2015-01-18  1.509773e+08 -122.423644  37.767802
# 2015-01-25  1.510900e+08 -122.423347  37.768943
# 2015-02-01  1.510146e+08 -122.423590  37.769007
# 2015-02-08  1.511378e+08 -122.422634  37.768326
# 2015-02-15  1.510528e+08 -122.423645  37.768649
# 2015-02-22  1.511358e+08 -122.423072  37.768851
# 2015-03-01  1.509891e+08 -122.422954  37.767481
# 2015-03-08  1.511361e+08 -122.423322  37.768836
# 2015-03-15  1.511553e+08 -122.422670  37.768033
# 2015-03-22  1.511990e+08 -122.421774  37.768298
# 2015-03-29  1.512421e+08 -122.423860  37.768752
# 2015-04-05  1.512982e+08 -122.424164  37.769370
# 2015-04-12  1.513533e+08 -122.422841  37.769390
# 2015-04-19  1.512471e+08 -122.423979  37.768687
# 2015-04-26  1.513609e+08 -122.424541  37.768698
# 2015-05-03  1.513139e+08 -122.425281  37.767770
# ...

# %%
df.resample('W').agg({'IncidntNum': 'mean'})
# Out:
#               IncidntNum
# Date
# 2015-01-04  1.511708e+08
# 2015-01-11  1.509222e+08
# 2015-01-18  1.509773e+08
# 2015-01-25  1.510900e+08
# 2015-02-01  1.510146e+08
# 2015-02-08  1.511378e+08
# 2015-02-15  1.510528e+08
# 2015-02-22  1.511358e+08
# 2015-03-01  1.509891e+08
# 2015-03-08  1.511361e+08
# 2015-03-15  1.511553e+08
# 2015-03-22  1.511990e+08
# 2015-03-29  1.512421e+08
# 2015-04-05  1.512982e+08
# 2015-04-12  1.513533e+08
# 2015-04-19  1.512471e+08
# 2015-04-26  1.513609e+08
# 2015-05-03  1.513139e+08
# 2015-05-10  1.513567e+08
# 2015-05-17  1.514088e+08
# 2015-05-24  1.514175e+08
# 2015-05-31  1.512957e+08
# 2015-06-07  1.514301e+08
# 2015-06-14  1.513774e+08
# 2015-06-21  1.515752e+08
# 2015-06-28  1.516136e+08
# 2015-07-05  1.515024e+08
# 2015-07-12  1.514091e+08
# 2015-07-19  1.516688e+08
# 2015-07-26  1.516672e+08
# 2015-08-02  1.516561e+08
# 2015-08-09  1.516652e+08
# 2015-08-16  1.516532e+08
# 2015-08-23  1.515328e+08
# 2015-08-30  1.515485e+08
# ...

# %% [markdown]
# # More Resources
#
# <a name="histfootnote">1</a>: [Histogram](https://en.wikipedia.org/wiki/Histogram)
#
# The matplotlib users' guide is at http://pageperso.lif.univ-mrs.fr/~francois.denis/IAAM1/Matplotlib.pdf.

# %% [markdown]
# For visualisation ideas and code see https://python-graph-gallery.com/:

# %%
# GeoPandas

> The goal of GeoPandas is to make working with geospatial data in python easier. 
It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface 
to multiple geometries to shapely.
GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.

[GeoPandas 0.4.0](http://geopandas.org/index.html#)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
