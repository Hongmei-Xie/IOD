# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.1 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

sns.set_context("poster")
sns.set(rc={'figure.figsize': (10, 6)})
sns.set_style("whitegrid")

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Use what you have learned so far.

# %%
# Read CSV
data = pd.read_csv('C:\\Users\\apple\\Downloads\\Sacramento_transactions.csv')

# %%
data.shape
# Out:
# (985, 12)

# %%
# Head
data.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
# Tail
data.tail()
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
# Check Null Values
data.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
########## Pipe output of DataFrame.info to buffer instead of sys.stdout, get
######     buffer content and writes to a text file:

import io
buffer = io.StringIO()
data.info(buf=buffer)
s = buffer.getvalue()
with open("data_info.txt", "w",
encoding="utf-8") as f:  # doctest: +SKIP
    f.write(s)

# %%
# Data Types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
# Zip is categorical value, should be string
data['zip'] = data['zip'].astype(str)

# %%
data.zip.describe()
# Out:
# count       985
# unique       68
# top       95648
# freq         72
# Name: zip, dtype: object

# %%
data.describe(include=[np.number])
# Out:
#              beds       baths       sq__ft          price    latitude  \
# count  985.000000  985.000000   985.000000     985.000000  985.000000
# mean     2.911675    1.776650  1314.916751  234144.263959   38.607732
# std      1.307932    0.895371   853.048243  138365.839085    0.145433
# min      0.000000    0.000000     0.000000    1551.000000   38.241514
# 25%      2.000000    1.000000   952.000000  145000.000000   38.482717
# 50%      3.000000    2.000000  1304.000000  213750.000000   38.626582
# 75%      4.000000    2.000000  1718.000000  300000.000000   38.695589
# max      8.000000    5.000000  5822.000000  884790.000000   39.020808
#
#         longitude
# count  985.000000
# mean  -121.355982
# std      0.138278
# min   -121.551704
# 25%   -121.446127
# 50%   -121.376220
# 75%   -121.295778
# max   -120.597599

# %%
data.describe(include=[object])
# Out:
#                    street        city    zip state         type  \
# count                 985         985    985   985          985
# unique                981          39     68     1            4
# top     7 CRYSTALWOOD CIR  SACRAMENTO  95648    CA  Residential
# freq                    2         439     72   985          917
#
#                            sale_date
# count                            985
# unique                             5
# top     Mon May 19 00:00:00 EDT 2008
# freq                             268

# %%
#data.describe(include=['category'])

# %%
data.describe(include='all').T
# Out:
#           count unique                           top freq     mean       std  \
# street      985    981             7 CRYSTALWOOD CIR    2      NaN       NaN
# city        985     39                    SACRAMENTO  439      NaN       NaN
# zip         985     68                         95648   72      NaN       NaN
# state       985      1                            CA  985      NaN       NaN
# beds        985    NaN                           NaN  NaN  2.91168   1.30793
# baths       985    NaN                           NaN  NaN  1.77665  0.895371
# sq__ft      985    NaN                           NaN  NaN  1314.92   853.048
# type        985      4                   Residential  917      NaN       NaN
# sale_date   985      5  Mon May 19 00:00:00 EDT 2008  268      NaN       NaN
# price       985    NaN                           NaN  NaN   234144    138366
# latitude    985    NaN                           NaN  NaN  38.6077  0.145433
# longitude   985    NaN                           NaN  NaN -121.356  0.138278
#
#                min      25%      50%      75%      max
# street         NaN      NaN      NaN      NaN      NaN
# city           NaN      NaN      NaN      NaN      NaN
# zip            NaN      NaN      NaN      NaN      NaN
# state          NaN      NaN      NaN      NaN      NaN
# beds             0        2        3        4        8
# baths            0        1        2        2        5
# sq__ft           0      952     1304     1718     5822
# type           NaN      NaN      NaN      NaN      NaN
# sale_date      NaN      NaN      NaN      NaN      NaN
# price         1551   145000   213750   300000   884790
# latitude   38.2415  38.4827  38.6266  38.6956  39.0208
# longitude -121.552 -121.446 -121.376 -121.296 -120.598

# %%
# Describe Data
data.describe().T
# Out:
#            count           mean            std          min            25%  \
# beds       985.0       2.911675       1.307932     0.000000       2.000000
# baths      985.0       1.776650       0.895371     0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243     0.000000     952.000000
# price      985.0  234144.263959  138365.839085  1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433    38.241514      38.482717
# longitude  985.0    -121.355982       0.138278  -121.551704    -121.446127
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.626582      38.695589      39.020808
# longitude    -121.376220    -121.295778    -120.597599

# %%
# Got min value 0 for beds, baths, sqft which does not seem correct.

# %%
data[data['beds'] == 0]
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 901  1530 TOPANGA LN Unit 204          LINCOLN  95648    CA     0      0
# 917            501 POPLAR AVE  WEST SACRAMENTO  95691    CA     0      0
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
#
#      sq__ft         type                     sale_date   price   latitude  \
# 73        0  Residential  Wed May 21 00:00:00 EDT 2008  206000  38.631481
# 89        0  Residential  Wed May 21 00:00:00 EDT 2008  244500  38.626671
# 100       0  Residential  Wed May 21 00:00:00 EDT 2008  263500  38.553867
# 121       0  Residential  Wed May 21 00:00:00 EDT 2008  320000  38.528575
# 126       0  Residential  Wed May 21 00:00:00 EDT 2008  339500  38.602416
# ..      ...          ...                           ...     ...        ...
# 901       0        Condo  Thu May 15 00:00:00 EDT 2008  138000  38.884150
# 917       0  Residential  Thu May 15 00:00:00 EDT 2008  165000  38.584526
# 934       0        Condo  Thu May 15 00:00:00 EDT 2008  188000  38.884170
# 947       0  Residential  Thu May 15 00:00:00 EDT 2008  200100  38.569943
# 970       0  Residential  Thu May 15 00:00:00 EDT 2008  224000  38.631026
#
#       longitude
# 73  -121.501880
# 89  -121.525970
# 100 -121.219141
# 121 -121.228600
# 126 -121.542965
# ..          ...
# 901 -121.270277
# 917 -121.534609
# 934 -121.270222
# 947 -121.527539
# 970 -121.501879
#
# [108 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
# Types of Data
data['type'].value_counts().plot(kind='bar')
plt.show()

# %%
# City
data['city'].value_counts().sort_values().plot(kind='barh', figsize=(15,10));

# %%
# Create another type which have 0 beds, baths, sqft

# %%
data.loc[data['beds'] == 0, 'type'] = 'Plot'
data.loc[73]
# Out:
# street                      17 SERASPI CT
# city                           SACRAMENTO
# zip                                 95834
# state                                  CA
# beds                                    0
# baths                                   0
# sq__ft                                  0
# type                                 Plot
# sale_date    Wed May 21 00:00:00 EDT 2008
# price                              206000
# latitude                          38.6315
# longitude                        -121.502
# Name: 73, dtype: object

# %%
data['state'].value_counts().plot(kind='bar');

# %%
# import the library
import folium
import pandas as pd

# Make an empty map
# 37.76, -122.45 is the initital location of SF, USA
m = folium.Map(location=[38.575764, -121.478851],  tiles='https://api.mapbox.com/styles/v1/mapbox/light-v10/tiles/{z}/{x}/{y}?access_token=mytoken',
    attr='mapbox',zoom_start=10)

# I can add circle/marker one by one on the map
for i in range(0, len(data.head(1000))):
    folium.Marker(
        location=[data.iloc[i]['latitude'], data.iloc[i]['longitude']]
    ).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bdb6874e000d42fdbb8da9e111c3c066%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bdb6874e000d42fdbb8da9e111c3c066%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bdb6874e000d42fdbb8da9e111c3c066%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bdb6874e000d42fdbb8da9e111c3c066%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.575764%2C%20-121.478851%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER

## Price is target varaible. Based on other predictor variables we'll predict price.

# %% [markdown]
# #### 2.2 List all possible variables which might be Predictor variable.

# %%
# ANSWER

## beds
## baths
## sqft
## Type

# %%
# Target Variable
Y = data['price']

# %%
# Predictor Variable
X = data['beds']

# %%
def draw_scatter_plot(X, Y):
    ### Plot the data
    # create a figure
    fig = plt.figure(figsize=(10,6))
    # get the axis of that figure
    ax = plt.gca()

    # plot a scatter plot on it with our data
    ax.scatter(X, Y, c='b')

    plt.show();

# %%
# beds
draw_scatter_plot(data['beds'], data['price'])

# %%
# beds
draw_scatter_plot(data['baths'], data['price'])

# %%
# beds
draw_scatter_plot(data['sq__ft'], data['price'])

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
data.corr()
# Out:
#                beds     baths    sq__ft     price  latitude  longitude
# beds       1.000000  0.839650  0.684041  0.342024 -0.291307  -0.053993
# baths      0.839650  1.000000  0.665690  0.416208 -0.235792   0.016582
# sq__ft     0.684041  0.665690  1.000000  0.333897 -0.383274  -0.177742
# price      0.342024  0.416208  0.333897  1.000000 -0.039573   0.284485
# latitude  -0.291307 -0.235792 -0.383274 -0.039573  1.000000   0.387925
# longitude -0.053993  0.016582 -0.177742  0.284485  0.387925   1.000000

# %%
### sq_ft is the best predictor.
### sqft got stong relationship with beds, baths

# %% [markdown]
# #### 2.4 What is the simplest way to predict price
#
# So we have information for 985 houses. What is the easiest way to predict price of a house?

# %%
# ANSWER
## Mean of Price
data['y_hat'] = data['price'].mean()

# %%
X = data['sq__ft']
Y = data['price']
Yhat = data['y_hat']

# %%
def draw_plot(X, Y, Yhat):
    ### Plot the data
    # create a figure
    fig = plt.figure(figsize=(10,6))
    # get the axis of that figure
    ax = plt.gca()

    # plot a scatter plot on it with our data
    ax.scatter(X, Y, c='b')
    ax.plot(X, Yhat, color='r');

    plt.show();

# %%
draw_plot(X, Y, Yhat)

# %% [markdown]
# #### 2.5 Find Resudals
#
# Find difference between actual value and predicted value. Use absolute value.

# %%
# ANSWER
res = abs(data['price'] - data['y_hat']).mean()
res
# Out:
# 103452.16956891476

# %% [markdown]
# #### 2.6  Predict Using Linear Regression
#
# [Simple Linear Regression](https://en.wikipedia.org/wiki/Simple_linear_regression#Fitting_the_regression_line)
#
# ### $$\hat{y} = \beta_0 + \beta_1 x$$
#
# > ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$
#
# and
#
# > ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$
#
# Given variables:
# - $\bar{y}$ : the sample mean of observed values $Y$
# - $\bar{x}$ : the sample mean of observed values $X$
# - $s_Y$ : the sample standard deviation of observed values $Y$
# - $s_X$ : the sample standard deviation of observed values $X$
# - $r_{XY}$ : the sample Pearson correlation coefficient between observed $X$ and $Y$

# %% [markdown]
# ##### 2.7 Define X, Y
#
# - X = Predictor Variable
# - Y = Target Variable

# %%
X = data['sq__ft']
Y = data['price']

# %% [markdown]
# ##### 2.7.A Calculate beta_1
#
#  ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$

# %%
Xbar = X.mean()
Ybar = Y.mean()
print(Xbar )
c=(Y - Ybar) * (X - Xbar)
print(type(Y-Ybar))
n = np.sum((Y - Ybar) * (X - Xbar)) 
d = np.sum(np.square(X - Xbar)) 
    
beta_1 = n/d
# Out:
# 1314.9167512690356
# <class 'pandas.core.series.Series'>

# %%
# ANSWER
def calculate_beta_1(X, Y):
    Xbar = X.mean()
    Ybar = Y.mean()
    
    n = np.sum((Y - Ybar) * (X - Xbar)) 
    d = np.sum(np.square(X - Xbar)) 
    
    beta_1 = n/d
    
    return beta_1

# %%
beta_1 = calculate_beta_1(X, Y)
beta_1
# Out:
# 54.158639688530755

# %% [markdown]
# ##### 2.7.B Calculate beta_0

# %% [markdown]
# ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$

# %%
# ANSWER
def calculate_beta_0(X, Y):
    
    Xbar = X.mean()
    Ybar = Y.mean()
    
    beta_0 = Ybar - calculate_beta_1(X, Y) * Xbar
    
    return beta_0

# %%
beta_0 = calculate_beta_0(X, Y)
beta_0
# Out:
# 162930.16140699777

# %% [markdown]
# ##### 2.7.C Find Yhat (Predicted Value Using Beta 0 and Beta 1)

# %% [markdown]
# ### $$\hat{y} = \beta_0 + \beta_1 x$$

# %%
# ANSWER
def calculate_yhat(x, b0, b1):
    return b0 + b1 * x

# %%
Yhat = calculate_yhat(X, beta_0, beta_1)
Yhat
# Out:
# 0      208206.784187
# 1      226133.293924
# 2      206040.438599
# 3      209073.322422
# 4      206094.597239
#            ...
# 980    286411.859897
# 981    242922.472227
# 982    228787.067268
# 983    254187.469282
# 984    236694.228663
# Name: sq__ft, Length: 985, dtype: float64

# %% [markdown]
# ##### 2.7.D Find Residuals

# %% [markdown]
# ### $$ \text{residual}_i = y_i - \hat{y}_i$$

# %%
def calculate_residual(Y, Yhat):
    res = Y - Yhat
    return res

# %%
resi = calculate_residual(Y, Yhat)
abs(resi)
# Out:
# 0      148984.784187
# 1      157921.293924
# 2      137160.438599
# 3      139766.322422
# 4      124194.597239
#            ...
# 980     53986.859897
# 981      8922.472227
# 982      6212.932732
# 983     18886.469282
# 984       956.228663
# Length: 985, dtype: float64

# %%
print(max(abs(resi)))
print(min(abs(resi)))
# Out:
# 716069.8385930022
# 136.20035461249063

# %% [markdown]
# ##### 2.7.E Find R-Square
#
# Write a function to calculate R- Square value.

# %% [markdown]
# The total sum of squares:
#
# ### $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The residual sum of squares:
#
# ### $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$
#
# $R^2$:
#
# ### $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$

# %%
def calculate_total_sum_of_square(Y):
    Ybar = np.mean(Y)
    SStot = np.square(Y - Ybar)
    SStot = np.sum(SStot)
    return SStot

# %%
def calculate_residual_sum_of_square(Y, Yhat):
    SSres = np.square(Y - Yhat)
    SSres = np.sum(SSres)
    return SSres

# %%
def calculate_r_square(Y, Yhat):
    SStot = calculate_total_sum_of_square(Y)
    SSres = calculate_residual_sum_of_square(Y, Yhat)
    Rsquare = 1 - (SSres/SStot)
    return Rsquare

# %%
calculate_r_square(Y, np.mean(Y))
# Out:
# 0.0

# %%
calculate_r_square(Y, calculate_yhat(X, beta_0, beta_1))
# Out:
# 0.11148717682951459

# %% [markdown]
# ##### 2.7.F [BONUS] Draw Plot of Predicted Line

# %%
draw_plot(X, Y, Yhat)

# %% [markdown]
# ##### 2.7.G [BONUS] Draw Plot of Predicted Line With Resudals

# %%
data['Yhat'] = Yhat

# %%
data.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude  \
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
#
#            y_hat           Yhat
# 0  234144.263959  208206.784187
# 1  234144.263959  226133.293924
# 2  234144.263959  206040.438599
# 3  234144.263959  209073.322422
# 4  234144.263959  206094.597239

# %%
# create a figure
fig = plt.figure(figsize=(18,8))
fig.set_figheight(8)
fig.set_figwidth(15)

# get the axis
ax = fig.gca()

# plot it
ax.scatter(x=X, y=Y, c='b')
ax.plot(X, Yhat, color='r');

# iterate over predictions
for _, row in data.iterrows():
    plt.plot((row['sq__ft'], row['sq__ft']), (row['price'], row['Yhat']), 'g-')

# %% [markdown]
# ### 3. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house.**

# %%
# ANSWER
xpred = 1204
xpred
# Out:
# 1204

# %%
beta_0
# Out:
# 162930.16140699777

# %%
beta_1
# Out:
# 54.158639688530755

# %%
Ypred = beta_1 * xpred + beta_0
Ypred
# Out:
# 228137.1635919888

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
