# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %% [markdown]
# ### Don't understand google.colab

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-aa6ef11158ce> in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#       3 import io
#       4 df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_csv("Employee-attrition.csv")
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns=df.columns
print(type(columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
index =df.index
index
print(type(index))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
data = df.values
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:

# %%
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# A:

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df['STATUS_YEAR'].dtypes
# Out:
# int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
df['job_title'].values[1:5]
# Out:
# array(['CEO', 'CEO', 'CEO', 'CEO'], dtype=object)

# %%
# A:

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Compensation Analyst                 20
# Investment Analyst                   20
# Auditor                              20
# ...

# %%
# A:

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
#2.C
def row_count(column_name):
    number_of_rows = 0
    
    number_of_rows =df.count()
    
    return number_of_rows

row_count("job_title")
# Out:
# EmployeeID             49653
# recorddate_key         49653
# birthdate_key          49653
# orighiredate_key       49653
# terminationdate_key    49653
# age                    49653
# length_of_service      49653
# city_name              49653
# department_name        49653
# job_title              49653
# store_name             49653
# gender_short           49653
# gender_full            49653
# termreason_desc        49653
# termtype_desc          49653
# STATUS_YEAR            49653
# STATUS                 49653
# BUSINESS_UNIT          49653
# dtype: int64

# %%
# A:

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
df.loc[49648,:]
# Out:
# EmployeeID                       8258
# recorddate_key         12/1/2015 0:00
# birthdate_key               5/28/1994
# orighiredate_key            8/19/2013
# terminationdate_key        12/30/2015
# age                                21
# length_of_service                   2
# city_name                   Valemount
# department_name                 Dairy
# job_title                Dairy Person
# store_name                         34
# gender_short                        M
# gender_full                      Male
# termreason_desc                Layoff
# termtype_desc             Involuntary
# STATUS_YEAR                      2015
# STATUS                     TERMINATED
# BUSINESS_UNIT                  STORES
# Name: 49648, dtype: object

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df.sort_values(by=['age'], inplace= False ,ascending= False)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48820        4138    2/1/2011 0:00     2/12/1946        8/20/1997
# 48520        2748    4/1/2007 0:00     4/24/1942       10/30/1993
# 48317        1567    4/1/2015 0:00      4/5/1950        4/27/1990
# 48336        1594    6/1/2015 0:00      6/5/1950        5/29/1990
# 48240        1441    8/1/2014 0:00     8/29/1949         1/1/1990
# ...           ...              ...           ...              ...
# 48077        8306  12/31/2013 0:00    10/15/1994        11/1/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 48037        8292  12/31/2013 0:00     8/30/1994        10/7/2013
# 48059        8300  12/31/2013 0:00     9/19/1994       10/18/2013
# 48132        8325  12/31/2013 0:00     12/7/1994       11/29/2013
#
#       terminationdate_key  age  length_of_service      city_name  \
# 48820           2/12/2011   65                 13         Surrey
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample(n = 3) 
df.sample(frac = 0.5)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 20952        4647  12/31/2007 0:00     7/31/1947         2/5/1999
# 3503         2016  12/31/2009 0:00    11/10/1952        9/10/1991
# 17345        4155  12/31/2009 0:00     3/17/1964         9/7/1997
# 7126         2604  12/31/2012 0:00     2/27/1956         6/7/1993
# 47683        8142  12/31/2015 0:00     5/16/1993         2/1/2013
# ...           ...              ...           ...              ...
# 38589        6595  12/31/2012 0:00     7/17/1981        11/3/2006
# 46900        7922  12/31/2012 0:00     9/17/1991        3/17/2012
# 2661         1877  12/31/2009 0:00     1/27/1952        4/12/1991
# 40042        6772  12/31/2009 0:00    12/29/1982        8/10/2007
# 29273        5621  12/31/2010 0:00      8/7/1973        8/24/2002
#
#       terminationdate_key  age  length_of_service        city_name  \
# 20952           7/31/2012   60                  8          Quesnel
# ...

# %%
df.sample()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 29445        5639  12/31/2015 0:00    10/13/1973        9/28/2002
#
#       terminationdate_key  age  length_of_service      city_name  \
# 29445            1/1/1900   42                 13  Prince George
#
#       department_name     job_title  store_name gender_short gender_full  \
# 29445           Dairy  Dairy Person          26            M        Male
#
#       termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 29445  Not Applicable  Not Applicable         2015  ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:
df.loc[df["job_title"] == "CEO"]
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 9            1/1/1900   61                 26  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
 df.groupby(by=["age"])

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:

df.loc[:,"age"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
df.loc[:,"age"].plot.box(sym='r+')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
plt.plot(df.loc[:,"age"], df.loc[:,"length_of_service"], '.', color='blue')

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A:
df.loc[:,"store_name"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %% [markdown]
# ## Don't understand the 括号的作用

# %%
df.loc[:,"age"].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %%
df.describe(include='all')
# Out:
#           EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# count   49653.000000            49653         49653            49653
# unique           NaN              130          5342             4415
# top              NaN  12/31/2013 0:00     4/27/1956        2/26/2006
# freq             NaN             5215            40               50
# mean     4859.495740              NaN           NaN              NaN
# std      1826.571142              NaN           NaN              NaN
# min      1318.000000              NaN           NaN              NaN
# 25%      3360.000000              NaN           NaN              NaN
# 50%      5031.000000              NaN           NaN              NaN
# 75%      6335.000000              NaN           NaN              NaN
# max      8336.000000              NaN           NaN              NaN
#
#        terminationdate_key           age  length_of_service  city_name  \
# ...

# %%
df.describe(include=['object'])
# Out:
#          recorddate_key birthdate_key orighiredate_key terminationdate_key  \
# count             49653         49653            49653               49653
# unique              130          5342             4415                1055
# top     12/31/2013 0:00     4/27/1956        2/26/2006            1/1/1900
# freq               5215            40               50               42450
#
#         city_name department_name    job_title gender_short gender_full  \
# count       49653           49653        49653        49653       49653
# unique         40              21           47            2           2
# top     Vancouver           Meats  Meat Cutter            F      Female
# freq        11211           10269         9984        25898       25898
#
#        termreason_desc   termtype_desc  STATUS BUSINESS_UNIT
# count            49653           49653   49653         49653
# unique               4               3       2             2
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
